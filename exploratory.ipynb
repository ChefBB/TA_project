# %%
import pandas as pd

path = '/Users/brunobarbieri/Library/CloudStorage/OneDrive-UniversityofPisa/TA_Project/data/'
df = pd.read_csv(path + 'lab_lem_merged.csv')
df
# Out:
#           id                   title          artist  year  views features  \
# 0          0  Something in the Water   Pokey LaFarge  2015  10902     {''}
# 1          0  Something in the Water   Pokey LaFarge  2015  10902     {''}
# 2          0  Something in the Water   Pokey LaFarge  2015  10902     {''}
# 3          0  Something in the Water   Pokey LaFarge  2015  10902     {''}
# 4          0  Something in the Water   Pokey LaFarge  2015  10902     {''}
# ...      ...                     ...             ...   ...    ...      ...
# 57955  11010       Lay It in My Hand  The Real Group  2009     71     {''}
# 57956  11011            Stop Calling    Lina Morgana  2008     74     {''}
# 57957  11011            Stop Calling    Lina Morgana  2008     74     {''}
# 57958  11011            Stop Calling    Lina Morgana  2008     74     {''}
# 57959  11011            Stop Calling    Lina Morgana  2008     74     {''}
#
#        is_country  is_pop  is_rap  is_rb  is_rock  stanza_number  is_chorus  \
# 0            True   False   False  False    False              0      False
# 1            True   False   False  False    False              1       True
# 2            True   False   False  False    False              2      False
# 3            True   False   False  False    False              4      False
# 4            True   False   False  False    False              5       True
# ...           ...     ...     ...    ...      ...            ...        ...
# 57955       False    True   False  False    False              6      False
# 57956       False    True   False  False    False              0      False
# 57957       False    True   False  False    False              1      False
# 57958       False    True   False  False    False              2       True
# 57959       False    True   False  False    False              3       True
#
#                                       lemmatized_stanzas         label
# 0      ['she', 'get', 'a', 'broke', 'down', 'el', 'ca...         anger
# 1      ['something', 'in', 'the', 'water', 'something...         anger
# 2      ['she', 'do', 'her', 'makeup', 'and', 'hair', ...  anticipation
# 3      ['my', 'hoosi', 'girl', 'be', 'so', 'fine', 's...          fear
# 4      ['something', 'in', 'the', 'water', 'something...          fear
# ...                                                  ...           ...
# 57955  ['come', 'and', 'release', 'your', 'confidence...         trust
# 57956  ['when', 'the', 'sun', 'kill', 'the', 'moon', ...         trust
# 57957  ['and', 'I', 'do', 'not', 'care', 'anymore', '...          fear
# 57958  ['stop', 'call', 'I', 'have', 'stop', 'care', ...          fear
# 57959  ['down', 'down', 'down', 'down', 'still', 'you...          fear
#
# [57960 rows x 15 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize= (10,6))
df.groupby('label').count()['id'].sort_values(ascending= False).plot(kind= 'bar')
plt.xlabel('Class')
plt.ylabel('Number of rows')
plt.xticks(rotation= 0.9)
plt.title('Number of occurrences for each class')
plt.grid(axis= 'y', alpha= 0.3)
plt.show()

plt.close()

# %%
from matplotlib.cm import get_cmap

data = df.groupby('label').count()['id'].sort_values(ascending= False)

percentages = (data / data.sum()) * 100
labels = [f"{label} ({value:.0f}%)" for label, value in zip(data.index, percentages)]

cmap = get_cmap('prism')
colors = [cmap(i / len(data)) for i in range(len(data))]

# Plot the pie chart
plt.figure(figsize=(10, 7))
plt.pie(
    data, 
    labels=labels,  # Use the custom labels
    colors= colors,
    startangle=90   # Rotate the chart to start at 90 degrees
)

# Add a title
plt.title('Distribution of Categories')
plt.show()

plt.show()

plt.close()
# Out:
# /var/folders/68/gjrvx3m51494g9gp2r93j3vh0000gn/T/ipykernel_96382/4045646171.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('prism')
